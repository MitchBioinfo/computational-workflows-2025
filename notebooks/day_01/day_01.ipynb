# %% [markdown]
# # Computational Workflows for biomedical data

# %% [markdown]
# Welcome to the course Computational Workflows for Biomedical Data. Over the next two weeks, you will learn how to leverage nf-core pipelines to analyze biomedical data and gain hands-on experience in creating your own pipelines, with a strong emphasis on Nextflow and nf-core.
#
# Course Structure:
#
# - Week 1: You will use a variety of nf-core pipelines to analyze a publicly available biomedical study.
# - Week 2: We will shift focus to learning the basics of Nextflow, enabling you to design and implement your own computational workflows.<br>
# - Final Project: The last couple of days, you will apply your knowledge to create a custom pipeline for analyzing biomedical data using Nextflow and the nf-core template.

# %% [markdown]
# ## Basics
#
# If you have not installed all required software, please do so now asap!
#
#
# If you already installed all software, please go on and start answering the questions in this notebook. If you have any questions, don't hesitate to approach us.

# %% [markdown]
# 1. What is nf-core?

# %% [markdown]
# nf-core is a community-driven project that provides high-quality, peer-reviewed bioinformatics pipelines built using Nextflow. These pipelines are designed to be reproducible, portable, and easy to use (FAIR).

# %% [markdown]
# 2. How many pipelines are there currently in nf-core?

# %% [markdown]
# 139

# %% [markdown]
# 3. Are there any non-bioinformatic pipelines in nf-core?

# %% [markdown]
# As far as the 139 pipelines sound, they all have an aspects of bioinformatics in them. But maybe some pipelines like rangeland seems to not fit particulary well with established field of bioinformatics.

# %% [markdown]
# 4. Let's go back a couple of steps. What is a pipeline and what do we use it for?

# %% [markdown]
# A series of streamlined processes concatinated to one workflow

# %% [markdown]
# 5. Why do you think nf-core adheres to strict guidelines?

# %% [markdown]
# Strict guidelines ensure that pipelines are reliable, reproducible, well-documented, and easy to maintain. This promotes best practices and makes collaboration easier.

# %% [markdown]
# 6. What are the main features of nf-core pipelines?

# %% [markdown]
# Documentation, CI Testing, Stable Releases , Run anywhere, OPen Source, Packaged software.
#
# These features enable Reproducability, FIndability, Accesability and Interoperable (FAIR)

# %% [markdown]
# ## Let's start using the pipelines

# %% [markdown]
# 1. Find the nf-core pipeline used to measure differential abundance of genes

# %%
# run the pipeline in a cell 
# to run bash in jupyter notebooks, simply use ! before the command
# e.g.

# !pwd


# For the tasks in the first week, please use the command line to run your commands and simply paste the commands you used in the respective cells!
# Out:
# /home/mitch/Dokumente/Worklflow/computational-workflows-2025/notebooks/day_01

# %%
# !gh auth login
# Out:
# ]11;?\]11;?\78? Where do you use GitHub?  [Use arrows to move, type to filter]
# > GitHub.com
#   Other
# 7

# %%
# run the pipeline in the test profile using docker containers
# make sure to specify the version you want to use (use the latest one)


# !nextflow run nf-core/differentialabundance --outdir results -profile test,docker
# Out:
#  N E X T F L O W   ~  version 25.04.7
#
# Pulling nf-core/differentialabundance ...
# WARN: Cannot read project manifest -- Cause: API rate limit exceeded -- Provide your GitHub user name and password to get a higher rate limit
# API rate limit exceeded -- Provide your GitHub user name and password to get a higher rate limit

# %% [markdown]
# (base) mitch@mitch-X555LAB:~$ nextflow run nf-core/differentialabundance --outdir results -profile test,docker
# nextflow: Befehl nicht gefunden.
# (base) mitch@mitch-X555LAB:~$ conda activate Mitch_env
# (Mitch_env) mitch@mitch-X555LAB:~$ nextflow run nf-core/differentialabundance --outdir results -profile test,docker
#
#  N E X T F L O W   ~  version 25.04.7
#
# Launching `https://github.com/nf-core/differentialabundance` [evil_pauling] DSL2 - revision: 3dd360fed0 [master]
#
# WARN: Access to undefined parameter `monochromeLogs` -- Initialise it to a default value eg. `params.monochromeLogs = some_value`
#
#
# ------------------------------------------------------
#                                         ,--./,-.
#         ___     __   __   __   ___     /,-._.--~'
#   |\ | |__  __ /  ` /  \ |__) |__         }  {
#   | \| |       \__, \__/ |  \ |___     \`-._,-`-,
#                                         `._,._,'
#   nf-core/differentialabundance v1.5.0-g3dd360f
# ------------------------------------------------------
# Core Nextflow options
#   revision                    : master
#   runName                     : evil_pauling
#   containerEngine             : docker
#   container                   : [RMARKDOWNNOTEBOOK:biocontainers/r-shinyngs:1.8.8--r43hdfd78af_0]
#   launchDir                   : /home/mitch
#   workDir                     : /home/mitch/work
#   projectDir                  : /home/mitch/.nextflow/assets/nf-core/differentialabundance
#   userName                    : mitch
#   profile                     : test,docker
#   configFiles                 :
#
# Input/output options
#   study_name                  : SRP254919
#   input                       : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.samplesheet.csv
#   contrasts                   : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.contrasts.csv
#   outdir                      : results
#
# Abundance values
#   matrix                      : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.salmon.merged.gene_counts.top1000cov.tsv
#   transcript_length_matrix    : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/rnaseq_expression/SRP254919.spoofed_lengths.tsv
#   affy_cel_files_archive      : null
#   querygse                    : null
#
# Observations (e.g. samples) options
#   observations_name_col       : sample
#
# Affy input options
#   affy_cdfname                : null
#
# Filtering
#   filtering_min_abundance     : 10
#
# Exploratory analysis
#   exploratory_main_variable   : contrasts
#   exploratory_log2_assays     : raw,normalised
#
# Differential analysis
#   differential_file_suffix    : .deseq2.results.tsv
#
# DESeq2 specific options (RNA-seq only)
#   deseq2_vst_nsub             : 500
#
# Limma specific options (microarray only)
#   limma_spacing               : null
#   limma_block                 : null
#   limma_correlation           : null
#
# GSEA
#   gsea_run                    : true
#
# gprofiler2
#   gprofiler2_correction_method: gSCS
#   gprofiler2_background_file  : auto
#
# Shiny app settings
#   shinyngs_shinyapps_account  : null
#   shinyngs_shinyapps_app_name : null
#
# Options related to gene set analysis
#   gene_sets_files             : https://raw.githubusercontent.com/nf-core/test-datasets/modules/data/genomics/mus_musculus/gene_set_analysis/mh.all.v2022.1.Mm.symbols.gmt
#
# Reporting options
#   report_title                : null
#   report_author               : null
#   report_contributors         : Jane Doe
# Director of Institute of Microbiology
# University of Smallville;John Smith
# PhD student
# Institute of Microbiology
# University of Smallville
#   report_description          : null
#   report_round_digits         : 3
#
# Reference genome options
#   gtf                         : https://ftp.ensembl.org/pub/release-81/gtf/mus_musculus/Mus_musculus.GRCm38.81.gtf.gz
#
# Institutional config options
#   config_profile_name         : Test profile
#   config_profile_description  : Minimal test dataset to check pipeline function
#
# Max job request options
#   max_cpus                    : 2
#   max_memory                  : 6.GB
#   max_time                    : 6.h
#
# !! Only displaying parameters that differ from the pipeline defaults !!
# ------------------------------------------------------
# If you use nf-core/differentialabundance for your analysis please cite:
#
# * The pipeline
#   https://doi.org/10.5281/zenodo.7568000
#
# * The nf-core framework
#   https://doi.org/10.1038/s41587-020-0439-x
#
# * Software dependencies
#   https://github.com/nf-core/differentialabundance/blob/master/CITATIONS.md
# ------------------------------------------------------
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF -
# [-        ] NFC…ENTIALABUNDANCE:GUNZIP_GTF | 0 of 1
# executor >  local (21)
# [03/8947da] NFC…ABUNDANCE:DIFFERENTIALABUNDANCE:GUNZIP_GTF (Mus_musculus.GRCm38.81.gtf.gz) [100%] 1 of 1 ✔
# [03/2c2a98] NFCORE_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:GTF_TO_TABLE (Mus_musculus) [100%] 1 of 1 ✔
# [14/5a4fa3] NFC…NTIALABUNDANCE:DIFFERENTIALABUNDANCE:VALIDATOR (SRP254919.samplesheet.csv) [100%] 1 of 1 ✔
# [96/9cfd62] NFC…ENTIALABUNDANCE:DIFFERENTIALABUNDANCE:CUSTOM_MATRIXFILTER ([id:SRP254919]) [100%] 1 of 1 ✔
# [a3/dc36ed] NFC…rry_hND6_, variable:treatment, reference:mCherry, target:hND6, blocking:]) [100%] 1 of 1 ✔
# [b4/84c9c0] NFC…riable:treatment, reference:mCherry, target:hND6, blocking:sample_number]) [100%] 2 of 2 ✔
# [0c/2c2f12] NFCORE_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:FILTER_DIFFTABLE (2)        [100%] 2 of 2 ✔
# [c6/f4bf37] NFC…CE:DIFFERENTIALABUNDANCE:CUSTOM_TABULARTOGSEAGCT (treatment_mCherry_hND6_) [100%] 1 of 1 ✔
# [2c/df3cf7] NFC…CE:DIFFERENTIALABUNDANCE:CUSTOM_TABULARTOGSEACLS (treatment_mCherry_hND6_) [100%] 2 of 2 ✔
# [1b/c7e470] NFCORE_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:TABULAR_TO_GSEA_CHIP (1)    [100%] 1 of 1 ✔
# [a2/36738e] NFC…RENTIALABUNDANCE:DIFFERENTIALABUNDANCE:GSEA_GSEA (treatment_mCherry_hND6_) [100%] 2 of 2 ✔
# [12/faebed] NFC…E_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:PLOT_EXPLORATORY (treatment) [100%] 1 of 1 ✔
# [32/345d0d] NFC…ERENTIALABUNDANCE:PLOT_DIFFERENTIAL (treatment_mCherry_hND6_sample_number) [100%] 2 of 2 ✔
# [60/a626a7] NFCORE_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:SHINYNGS_APP (SRP254919)    [100%] 1 of 1 ✔
# [11/8c8995] NFC…_DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:RMARKDOWNNOTEBOOK (SRP254919) [100%] 1 of 1 ✔
# [dc/72a265] NFC…DIFFERENTIALABUNDANCE:DIFFERENTIALABUNDANCE:MAKE_REPORT_BUNDLE (SRP254919) [100%] 1 of 1 ✔
# Completed at: 29-Sep-2025 12:46:27
# Duration    : 33m 7s
# CPU hours   : 0.1
# Succeeded   : 21

# %%
# repeat the run. What did change?
# much faster run1: 30min run2: 5min
#probabily because the files are already downloaded

# %% [markdown]
# Completed at: 29-Sep-2025 13:53:33
# Duration    : 5m 2s
# CPU hours   : 0.1
# Succeeded   : 21

# %%
# now set -resume to the command. What did change?
# !nextflow run nf-core/differentialabundance --outdir results -profile test,docker -resume

# %% [markdown]
# 1min 15s _
# here the fastest because the chaches could be used
# ![image.png](attachment:image.png)

# %% [markdown]
# Check out the current directory. Next to the outdir you specified, what else has changed?

# %%
# delete the work directory and run the pipeline again using -resume. What did change?

# %% [markdown]
# What changed?
#
# the hashcode at the start are the same so it can resume the analysis

# %% [markdown]
# ## Lets look at the results

# %% [markdown]
# ### What is differential abundance analysis?

# %% [markdown]
# Give the most important plots from the report:

# %% [markdown]
# treatment_mCherry_hND6_.deseq2.dispersion.png
#
# ![treatment_mCherry_hND6_.deseq2.dispersion.png](attachment:treatment_mCherry_hND6_.deseq2.dispersion.png)
#
#
#
#  - X-Achse: Mean Expression (baseMean)
#  - Y-Achse: Dispersion
#  - Black Dots: Gene-spezific Dispersionen
#  - Rote Linie: Fitted dispersion trend
#  - Blaue Punkte: Final dispersion estimates

# %% [markdown]
# ![boxplot.png](attachment:boxplot.png) ![density.png](attachment:density.png) ![mad_correlation.png](attachment:mad_correlation.png) ![pca2d.png](attachment:pca2d.png)
