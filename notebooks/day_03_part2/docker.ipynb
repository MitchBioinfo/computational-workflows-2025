# %% [markdown]
# # A short introduction to containerized software
#
# After spending time using nf-core pipelines to answer bioinformatic questions, we will focus on the processes that lie behind these pipelines now.
#
# Today, we will focus on containerization, namely via Docker.

# %% [markdown]
# 1. Check if Docker is installed.

# %%
# !docker info
# Out:
# Client:
#  Version:    28.1.1+1
#  Context:    default
#  Debug Mode: false
#  Plugins:
#   buildx: Docker Buildx (Docker Inc.)
#     Version:  v0.20.1
#     Path:     /usr/libexec/docker/cli-plugins/docker-buildx
#   compose: Docker Compose (Docker Inc.)
#     Version:  v2.33.1
#     Path:     /usr/libexec/docker/cli-plugins/docker-compose
#
# Server:
#  Containers: 1
#   Running: 0
#   Paused: 0
#   Stopped: 1
#  Images: 12
#  Server Version: 28.1.1+1
#  Storage Driver: overlay2
#   Backing Filesystem: extfs
#   Supports d_type: true
#   Using metacopy: false
#   Native Overlay Diff: true
#   userxattr: false
#  Logging Driver: json-file
#  Cgroup Driver: systemd
#  Cgroup Version: 2
#  Plugins:
#   Volume: local
#   Network: bridge host ipvlan macvlan null overlay
#   Log: awslogs fluentd gcplogs gelf journald json-file local splunk syslog
#  Swarm: inactive
#  Runtimes: io.containerd.runc.v2 runc
#  Default Runtime: runc
#  Init Binary: docker-init
#  containerd version: 05044ec0a9a75232cad458027ca83437aae3f4da
#  runc version:
#  init version: de40ad0
#  Security Options:
#   apparmor
#   seccomp
#    Profile: builtin
#   cgroupns
#  Kernel Version: 6.14.0-32-generic
#  Operating System: Ubuntu Core 22
#  OSType: linux
#  Architecture: x86_64
#  CPUs: 4
#  Total Memory: 11.58GiB
#  Name: mitch-X555LAB
#  ID: f5e85b24-596e-4410-a85a-e966c21f4a07
#  Docker Root Dir: /var/snap/docker/common/var-lib-docker
#  Debug Mode: false
#  Experimental: false
#  Insecure Registries:
#   ::1/128
#   127.0.0.0/8
#  Live Restore Enabled: false

# %% [markdown]
# ### What is a container?
#
# it is a light, portable environment with all dependencies for configuration included

# %% [markdown]
# ### Why do we use containers?
#
# reproducable, no dependancies of environment (Hardware),portable anywhere any pc.

# %% [markdown]
# ### What is a docker image?
#
# Frozen state of a filesystem with software installed

# %% [markdown]
# ### Let's run our first docker image:

# %% [markdown]
# ### Login to docker

# %%
# This you need to do on the command line directly
# !docker login
# Out:
# USING WEB-BASED LOGIN
#
# i Info → To sign in with credentials on the command line, use 'docker login -u <username>'
#
#
# Your one-time device confirmation code is: BQQJ-FHBJ
# Press ENTER to open your browser or submit your device code here: https://login.docker.com/activate
#
# Waiting for authentication in the browser…
# login canceled
# ^C

# %% [markdown]
# ### Run your first docker container

# %%
# !docker run hello-world
# Out:
# Hello from Docker!
# This message shows that your installation appears to be working correctly.
#
# To generate this message, Docker took the following steps:
#  1. The Docker client contacted the Docker daemon.
#  2. The Docker daemon pulled the "hello-world" image from the Docker Hub.
#     (amd64)
#  3. The Docker daemon created a new container from that image which runs the
#     executable that produces the output you are currently reading.
#  4. The Docker daemon streamed that output to the Docker client, which sent it
#     to your terminal.
#
# To try something more ambitious, you can run an Ubuntu container with:
#  $ docker run -it ubuntu bash
#
# Share images, automate workflows, and more with a free Docker ID:
#  https://hub.docker.com/
#
# For more examples and ideas, visit:
#  https://docs.docker.com/get-started/

# %% [markdown]
# ### Find the container ID

# %%
#find container ID
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED          STATUS                      PORTS     NAMES
# 2537a472a813   hello-world   "/hello"   10 minutes ago   Exited (0) 10 minutes ago             naughty_shtern
# e6788864ccc4   hello-world   "/hello"   2 days ago       Exited (0) 2 days ago                 agitated_fermi

# %% [markdown]
# ### Delete the container again, give prove its deleted

# %%
# !docker rm 2537a472a813
# Out:
# 2537a472a813

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED      STATUS                  PORTS     NAMES
# e6788864ccc4   hello-world   "/hello"   2 days ago   Exited (0) 2 days ago             agitated_fermi

# %% [markdown]
# ### FASTQC is a very useful tool as you've learned last week. Let's try and run it from command line
#
# Link to the software: https://www.bioinformatics.babraham.ac.uk/projects/fastqc/

# %% [markdown]
# Please describe the steps you took to download and run the software for the example fastq file from last week below:

# %% [markdown]
# 1. download fastqc
# 2. chmod +x fastqc
# 3. create the java environemnt needed
# 4. run it

# %% [markdown]
# ### Very well, now let's try to make use of its docker container
#
# 1. create a container holding fastqc using seqera containers (https://seqera.io/containers/)
# 2. use the container to generate a fastqc html of the example fastq file

# %%
# pull the container
# !docker pull community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# Out:
# 0.12.1--af7a5314d5015c29: Pulling from library/fastqc
#
# 2b0c44d2: Pulling fs layer
# b097362e: Pulling fs layer
# a01cff0b: Pulling fs layer
# b700ef54: Pulling fs layer
# 97a3ef36: Pulling fs layer
# 74b0f85e: Pulling fs layer
# c00c10a5: Pulling fs layer
# 7ea432cc: Pulling fs layer
# d6c3110d: Waiting fs layer
# a16bbe82: Pulling fs layer
# 47592a0a: Pulling fs layer
# acc3b8ff: Pulling fs layer
# c6865366: Pull complete 8.2MB/368.2MBBDownloading  206.9MB/368.2MBDigest: sha256:b7f6caf359264cf86da901b0aa5f66735a6506fcfbf103c66db6987253ad44c1
# Status: Downloaded newer image for community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29
# community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29

# %%
# run the container and save the results to a new "fastqc_results" directory

# !mkdir -p fastqc_results

# %%
# !ls -la /home/mitch/Dokumente/Worklflow/computational-workflows-2025/test_fastq_small/
# Out:
# insgesamt 3608
# drwxrwxr-x  2 mitch mitch   4096 Okt  1 13:59 .
# drwxrwxr-x 10 mitch mitch   4096 Okt  1 13:53 ..
# -rw-rw-r--  1 mitch mitch 447334 Sep 28  2017 Test01_L001_R1_001.fastq
# -rw-rw-r--  1 mitch mitch  93310 Okt  1 13:59 Test01_L001_R1_001.zip
# -rw-rw-r--  1 mitch mitch 446240 Sep 28  2017 Test01_L001_R2_001.fastq
# -rw-rw-r--  1 mitch mitch 447253 Sep 28  2017 Test02_L001_R1_001.fastq
# -rw-rw-r--  1 mitch mitch 446289 Sep 28  2017 Test02_L001_R2_001.fastq
# -rw-rw-r--  1 mitch mitch 447630 Sep 28  2017 Test03_L001_R1_001.fastq
# -rw-rw-r--  1 mitch mitch 446788 Sep 28  2017 Test03_L001_R2_001.fastq
# -rw-rw-r--  1 mitch mitch 447066 Sep 28  2017 Test04_L001_R1_001.fastq
# -rw-rw-r--  1 mitch mitch 446204 Sep 28  2017 Test04_L001_R2_001.fastq

# %%
# !docker run --rm \
    -v /home/mitch/Dokumente/Worklflow/computational-workflows-2025/test_fastq_small:/input \
    -v $(pwd)/fastqc_results:/output \
    community.wave.seqera.io/library/fastqc:0.12.1--af7a5314d5015c29 \
    sh -c "fastqc /input/*.fastq -o /output"
# Out:
# null
# null
# null
# null
# null
# null
# null
# null
# Started analysis of Test01_L001_R1_001.fastq
# Analysis complete for Test01_L001_R1_001.fastq
# Started analysis of Test01_L001_R2_001.fastq
# Analysis complete for Test01_L001_R2_001.fastq
# Started analysis of Test02_L001_R1_001.fastq
# Analysis complete for Test02_L001_R1_001.fastq
# Started analysis of Test02_L001_R2_001.fastq
# Analysis complete for Test02_L001_R2_001.fastq
# Started analysis of Test03_L001_R1_001.fastq
# Analysis complete for Test03_L001_R1_001.fastq
# Started analysis of Test03_L001_R2_001.fastq
# Analysis complete for Test03_L001_R2_001.fastq
# Started analysis of Test04_L001_R1_001.fastq
# Analysis complete for Test04_L001_R1_001.fastq
# Started analysis of Test04_L001_R2_001.fastq
# Analysis complete for Test04_L001_R2_001.fastq

# %% [markdown]
# ### Now that you know how to use a docker container, which approach was easier and which approach will be easier in the future?
#
# Probably the first one for the single use of a tool I think if moe tools might be neccessary a container structure makes more sense, especially if you need a lotof dependancies for a single tool (java etc.) If your environemtn already satisfy these conditions simply downloading the tool is easier.

# %% [markdown]
# ### What would you say, which approach is more reproducible?
#
# SInce there might be different dependancies a container is way more reproducible since this are always described
#
# I wasnt able to download the fastq files so i downloaded a test fastq file.
# My suggestions that the fastq container was used in the nextflow pipeline the results should be identical, while the fastqc manually might differ a bit.

# %% [markdown]
# ### Compare the file to last weeks fastqc results, are they identical?
# ### Is the fastqc version identical?

# %% [markdown]
# ## Dockerfiles
#
# We now used Docker containers and images directly to boost our research.
#
# Let's create our own toy Dockerfile including the "cowsay" tool (https://en.wikipedia.org/wiki/Cowsay)
#
# Hints:
# 1. Docker is Linux, so you need to know the apt-get command to install "cowsay"

# %%
# !docker build -t my-cowsay -f my_dockerfile .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (0/1)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
# [+] Building 0.3s (1/1)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.0s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.1s
# [+] Building 0.6s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.4s
# [+] Building 0.9s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 1.1s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.7s
# [+] Building 1.2s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.4s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.0s
# [+] Building 1.5s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
# [+] Building 1.7s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.3s
# [+] Building 1.8s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
# [+] Building 2.0s (1/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.6s
# [+] Building 2.0s (2/2)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
# [+] Building 2.1s (4/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
# [+] Building 2.2s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.1s
# [+] Building 2.3s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.2s
# [+] Building 2.5s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.4s
# [+] Building 2.7s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.6s
# [+] Building 2.8s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b 0B / 30.26MB  0.7s
# [+] Building 3.0s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  0.9s
# [+] Building 3.2s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 1.05MB / 30.26MB  1.1s
# [+] Building 3.3s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  1.2s
# [+] Building 3.4s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 2.10MB / 30.26MB  1.3s
# [+] Building 3.6s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 3.15MB / 30.26MB  1.5s
# [+] Building 3.7s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 3.15MB / 30.26MB  1.6s
# [+] Building 3.9s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  1.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  1.8s
# [+] Building 4.0s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  1.9s
# [+] Building 4.1s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 4.19MB / 30.26MB  2.0s
# [+] Building 4.2s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  2.1s
# [+] Building 4.4s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  2.3s
# [+] Building 4.5s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 5.24MB / 30.26MB  2.4s
# [+] Building 4.7s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 6.29MB / 30.26MB  2.6s
# [+] Building 4.9s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  2.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  2.8s
# [+] Building 5.1s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  3.0s
# [+] Building 5.2s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 7.34MB / 30.26MB  3.1s
# [+] Building 5.4s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.3s
# [+] Building 5.5s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 8.39MB / 30.26MB  3.4s
# [+] Building 5.7s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  3.6s
# [+] Building 5.9s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  3.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  3.8s
# [+] Building 6.0s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.0s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  3.9s
# [+] Building 6.1s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6 9.44MB / 30.26MB  4.0s
# [+] Building 6.3s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 10.49MB / 30.26MB  4.2s
# [+] Building 6.5s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 10.49MB / 30.26MB  4.4s
# [+] Building 6.7s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 11.53MB / 30.26MB  4.6s
# [+] Building 6.9s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  4.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 11.53MB / 30.26MB  4.8s
# [+] Building 7.1s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 11.53MB / 30.26MB  5.0s
# [+] Building 7.3s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  5.2s
# [+] Building 7.4s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.4s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  5.3s
# [+] Building 7.6s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 12.58MB / 30.26MB  5.5s
# [+] Building 7.8s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  5.7s
# [+] Building 7.9s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  5.9s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  5.8s
# [+] Building 8.1s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.1s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 13.63MB / 30.26MB  6.0s
# [+] Building 8.2s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.2s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  6.1s
# [+] Building 8.3s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.3s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  6.2s
# [+] Building 8.5s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.5s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  6.4s
# [+] Building 8.6s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  6.5s
# [+] Building 8.7s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.7s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 14.68MB / 30.26MB  6.6s
# [+] Building 8.8s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  6.8s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d 15.73MB / 30.26MB  6.7s
# [+] Building 8.9s (3/5)                                          docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
# ...
#  => => # Unpacking libtext-charwidth-perl (0.04-10+b1) ...
#  => => # Selecting previously unselected package cowsay.
#  => => # Preparing to unpack .../7-cowsay_3.03+dfsg2-8_all.deb ...
#  => => # Unpacking cowsay (3.03+dfsg2-8) ...
#  => => # Setting up libtext-charwidth-perl (0.04-10+b1) ...
# [+] Building 36.5s (4/5)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  18.9s
#  => => # Setting up netbase (6.3) ...
#  => => # Setting up libgdbm6:amd64 (1.19-2) ...
#  => => # Setting up libgdbm-compat4:amd64 (1.19-2) ...
#  => => # Setting up libperl5.32:amd64 (5.32.1-4+deb11u4) ...
#  => => # Setting up perl (5.32.1-4+deb11u4) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
# [+] Building 36.7s (4/5)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.0s
#  => => # Setting up libgdbm6:amd64 (1.19-2) ...
#  => => # Setting up libgdbm-compat4:amd64 (1.19-2) ...
#  => => # Setting up libperl5.32:amd64 (5.32.1-4+deb11u4) ...
#  => => # Setting up perl (5.32.1-4+deb11u4) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
# [+] Building 36.8s (4/5)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => => # Setting up libgdbm6:amd64 (1.19-2) ...
#  => => # Setting up libgdbm-compat4:amd64 (1.19-2) ...
#  => => # Setting up libperl5.32:amd64 (5.32.1-4+deb11u4) ...
#  => => # Setting up perl (5.32.1-4+deb11u4) ...
#  => => # Setting up cowsay (3.03+dfsg2-8) ...
#  => => # Processing triggers for libc-bin (2.31-13+deb11u13) ...
# [+] Building 36.9s (5/5)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#
#
#
#
#
#
# [+] Building 37.0s (5/6)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.1s
#  => => exporting layers                                                    0.1s
# [+] Building 37.2s (5/6)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 37.3s (5/6)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.4s
#  => => exporting layers                                                    0.4s
# [+] Building 37.5s (5/6)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 37.6s (5/6)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.7s
#  => => exporting layers                                                    0.7s
# [+] Building 37.7s (5/6)                                         docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 37.7s (6/6) FINISHED                                docker:default
#  => [internal] load build definition from my_dockerfile                    0.2s
#  => => transferring dockerfile: 843B                                       0.1s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.7s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => [1/2] FROM docker.io/library/debian:bullseye-slim@sha256:f807f4b1600  15.6s
#  => => resolve docker.io/library/debian:bullseye-slim@sha256:f807f4b16002  0.0s
#  => => sha256:f807f4b16002c623115b0247dca6a55711c6b1ae821 4.54kB / 4.54kB  0.0s
#  => => sha256:6d2307e95018a7a0bf263ca5ec988b1a9d92ab2e3e8 1.02kB / 1.02kB  0.0s
#  => => sha256:78305db6185d9638283714b8845ca305a105d7b17060130 453B / 453B  0.0s
#  => => sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6 30.26MB / 30.26MB  12.6s
#  => => extracting sha256:4eb1dd59a73886acc6a3cc9d4c8f8e66d1fd6ba6d6195b05  2.6s
#  => [2/2] RUN apt-get update && apt-get install -y cowsay && apt-get cle  19.2s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
#  => => writing image sha256:991afb26a5b65eb6df41e23c489b1ecd3afa7884d31fd  0.0s
#  => => naming to docker.io/library/my-cowsay                               0.0s

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE         COMMAND    CREATED      STATUS                  PORTS     NAMES
# e6788864ccc4   hello-world   "/hello"   2 days ago   Exited (0) 2 days ago             agitated_fermi

# %%
# !docker images | grep my-cowsay

# Run the cowsay container if the image exists
# !docker run my-cowsay cowsay "Hello from my Docker container!"
# Out:
# my-cowsay                                                  latest                     991afb26a5b6   6 minutes ago   128MB
#  _________________________________
# < Hello from my Docker container! >
#  ---------------------------------
#         \   ^__^
#          \  (oo)\_______
#             (__)\       )\/\
#                 ||----w |
#                 ||     ||

# %% [markdown]
# ### Explain the RUN and ENV lines you added to the file

# %% [markdown]
# Run runs the commands
# env creates the variable to be called

# %% [markdown]
# ## Let's do some bioinformatics with the docker file and create a new docker file that holds the salmon tool used in rnaseq
#
# To do so, use "curl" in your new dockerfile to get salmon from https://github.com/COMBINE-lab/salmon/releases/download/v1.5.2/salmon-1.5.2_linux_x86_64.tar.gz

# %%
# use the file "salmon_docker" in this directory to build a new docker image

# !docker build -t my-salmon -f salmon_docker .
# Out:
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/0)  docker:default
# [+] Building 0.0s (0/1)                                          docker:default
# [+] Building 0.2s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.2s
# [+] Building 0.3s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.3s
# [+] Building 0.5s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.5s
# [+] Building 0.6s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.6s
# [+] Building 0.8s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.8s
# [+] Building 0.9s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    0.9s
# [+] Building 1.1s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.1s
# [+] Building 1.2s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.2s
# [+] Building 1.4s (1/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.4s
# [+] Building 1.5s (2/2)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
# [+] Building 1.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.2s
# [+] Building 1.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.3s
# [+] Building 2.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.5s
# [+] Building 2.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.5s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
# [+] Building 2.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.6s
#  => => # Get:1 http://deb.debian.org/debian bullseye InRelease [75.1 kB]
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
# [+] Building 2.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  0.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.6s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 2.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  1.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 3.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  2.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.6s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 4.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  3.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.6s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 5.9s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 6.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.5s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 6.2s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 6.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  4.8s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 6.5s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 6.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.1s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 6.8s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.3s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 7.0s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.4s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 7.1s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.6s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 7.3s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.7s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 7.4s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  5.9s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 7.6s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  6.0s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
#  => => # Get:3 http://deb.debian.org/debian bullseye-updates InRelease [44.0 kB
#  => => # ]
#  => => # Get:4 http://deb.debian.org/debian bullseye/main amd64 Packages [8066
#  => => # kB]
# [+] Building 7.7s (4/6)                                          docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     ap  6.2s
#  => => # Get:2 http://deb.debian.org/debian-security bullseye-security InReleas
#  => => # e [27.2 kB]
# ...
#  => => # 100 51.0M  100 51.0M    0     0  2876k      0  0:00:18  0:00:18 --:--:
#  => => # -- 3302k
# [+] Building 41.8s (5/6)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.8s
#  => => #  75 51.0M   75 38.4M    0     0  2755k      0  0:00:18  0:00:14  0:00:
#  => => #  81 51.0M   81 41.6M    0     0  2785k      0  0:00:18  0:00:15  0:00:
#  => => #  87 51.0M   87 44.7M    0     0  2810k      0  0:00:18  0:00:16  0:00:
#  => => #  93 51.0M   93 47.7M    0     0  2826k      0  0:00:18  0:00:17  0:00:
#  => => # 100 51.0M  100 51.0M    0     0  2876k      0  0:00:18  0:00:18 --:--:
#  => => # -- 3302k
# [+] Building 41.9s (6/6)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#
#
#
#
#
#
# [+] Building 42.1s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     0.2s
#  => => exporting layers                                                    0.2s
# [+] Building 42.2s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     0.3s
#  => => exporting layers                                                    0.3s
# [+] Building 42.4s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     0.5s
#  => => exporting layers                                                    0.5s
# [+] Building 42.5s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     0.6s
#  => => exporting layers                                                    0.6s
# [+] Building 42.7s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     0.8s
#  => => exporting layers                                                    0.8s
# [+] Building 42.8s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     0.9s
#  => => exporting layers                                                    0.9s
# [+] Building 43.0s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     1.1s
#  => => exporting layers                                                    1.1s
# [+] Building 43.1s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     1.2s
#  => => exporting layers                                                    1.2s
# [+] Building 43.3s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     1.4s
#  => => exporting layers                                                    1.4s
# [+] Building 43.4s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     1.5s
#  => => exporting layers                                                    1.5s
# [+] Building 43.6s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     1.7s
#  => => exporting layers                                                    1.7s
# [+] Building 43.7s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     1.8s
#  => => exporting layers                                                    1.8s
# [+] Building 43.9s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     2.0s
#  => => exporting layers                                                    2.0s
# [+] Building 44.0s (6/7)                                         docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
# [+] Building 44.0s (7/7) FINISHED                                docker:default
#  => [internal] load build definition from salmon_docker                    0.0s
#  => => transferring dockerfile: 599B                                       0.0s
#  => [internal] load metadata for docker.io/library/debian:bullseye-slim    1.5s
#  => [internal] load .dockerignore                                          0.0s
#  => => transferring context: 2B                                            0.0s
#  => CACHED [1/3] FROM docker.io/library/debian:bullseye-slim@sha256:f807f  0.0s
#  => [2/3] RUN apt-get update &&     apt-get install -y curl tar &&     a  21.5s
#  => [3/3] RUN curl -L https://github.com/COMBINE-lab/salmon/releases/dow  18.9s
#  => exporting to image                                                     2.1s
#  => => exporting layers                                                    2.1s
#  => => writing image sha256:a3c7f1dda93f3fe75203ac2e0f1663acfc1b609e704ed  0.0s
#  => => naming to docker.io/library/my-salmon                               0.0s

# %%
# build the image
# !docker images | grep my-salmon
# Out:
# my-salmon                                                  latest                     a3c7f1dda93f   About a minute ago   306MB

# %%
# run the docker image to give out the version of salmon
# !docker run my-salmon salmon --version
# Out:
# salmon 1.5.2

# %% [markdown]
# ## Do you think bioinformaticians have to create a docker image every time they want to run a tool?
#
# create no, they most likely encounter docker images for preexisting tools and can simply get them from container webpages suxh as hub.docker etc.
#
# Find the salmon docker image online and run it on your computer.
#
# What is https://biocontainers.pro/ ?
#
# For me it seems like an educational site that teaches all about container, guidlines, best practices etc.

# %%
# !docker pull combinelab/salmon #https://hub.docker.com/r/combinelab/salmon
# Out:
# Using default tag: latest
# latest: Pulling from combinelab/salmon
#
# 7f213c76: Pulling fs layer
# 1ed9ab84: Pulling fs layer
# 0bdd40c3: Pulling fs layer
# 893c1bc1: Pulling fs layer
# Digest: sha256:cefd8bb0b2ed9b07f22b5f0fc317ddda540e5b0dc00810d1ff0d92fee5d80370[5ADownloading  14.54MB/16.42MB
# Status: Downloaded newer image for combinelab/salmon:latest
# docker.io/combinelab/salmon:latest

# %%
# !docker run combinelab/salmon salmon --version
# Out:
# salmon 1.10.3

# %%
# !docker ps -a
# Out:
# CONTAINER ID   IMAGE               COMMAND                  CREATED          STATUS                      PORTS     NAMES
# ed0ba9aac3d3   combinelab/salmon   "salmon --version"       40 seconds ago   Exited (0) 38 seconds ago             gifted_wiles
# 6cbbdb97a505   my-salmon           "salmon --version"       12 minutes ago   Exited (0) 12 minutes ago             jolly_joliot
# df4cb6802055   my-salmon           "bash"                   14 minutes ago   Exited (0) 14 minutes ago             determined_yalow
# b47ca001901b   my-cowsay           "cowsay 'Hello from …"   19 hours ago     Exited (0) 19 hours ago               objective_easley
# e6788864ccc4   hello-world         "/hello"                 2 days ago       Exited (0) 2 days ago                 agitated_fermi

# %% [markdown]
# ## Are there other ways to create Docker (or Apptainer) images?
# -dockerfiles
# -tools like Kaniko?
# -clouds
#
#
# What is https://seqera.io/containers/ ?
#
# cool tool to find different container images for different tools!
# Easy to find with a search and easy to install
